# %%
import pandas as pd
times_df = pd.read_csv("archive/times-person-of-the-year-latest.csv")

# %%
times_df
# Out:
#      Year               Honor                   Name        Country  \
# 0    1927     Man of the Year      Charles Lindbergh  United States
# 1    1928     Man of the Year        Walter Chrysler  United States
# 2    1929     Man of the Year          Owen D. Young  United States
# 3    1930     Man of the Year         Mahatma Gandhi          India
# 4    1931     Man of the Year           Pierre Laval         France
# ..    ...                 ...                    ...            ...
# 107  2020  Person of the Year              Joe Biden  United States
# 108  2020  Person of the Year          Kamala Harris  United States
# 109  2021  Person of the Year              Elon Musk  United States
# 110  2022  Person of the Year     Volodymyr Zelensky        Ukraine
# 111  2022  Person of the Year  The Spirit of Ukraine        Ukraine
#
#      Birth Year  Death Year  \
# 0        1902.0      1974.0
# 1        1875.0      1940.0
# 2        1874.0      1962.0
# 3        1869.0      1948.0
# ...

# %%
times_df.isna().sum()
# Out:
# Year             0
# Honor            0
# Name             0
# Country          7
# Birth Year      18
# Death Year      57
# Title           18
# Category         1
# Context         22
# Unnamed: 9      99
# Unnamed: 10    109
# dtype: int64

# %% [markdown]
# ## Country with the most Times nomination

# %%
times_df["Country"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Most Popular type of awards

# %%
times_df["Honor"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
times_df[(times_df["Honor"] == "Person of the Century") | (times_df["Honor"] == "Man of the Decade")]
# Out:
#     Year                  Honor               Name        Country  Birth Year  \
# 67  1989      Man of the Decade  Mikhail Gorbachev   Soviet Union      1931.0
# 82  1999  Person of the Century    Albert Einstein  United States         NaN
#
#     Death Year                          Title  Category               Context  \
# 67         NaN  President of the Soviet Union  Politics  Democratic Elections
# 82         NaN                            NaN   Science                   NaN
#
#    Unnamed: 9 Unnamed: 10
# 67        NaN         NaN
# 82        NaN         NaN

# %% [markdown]
# ## Most popular sector

# %%
times_df["Category"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Average age of Times nominee at year of award

# %%
times_df["Age when recieving honor"] = times_df["Year"] - times_df["Birth Year"]
times_df["Age when recieving honor"].plot(kind = "bar")
# Out:
# <Axes: >

# %%
times_single_person_df = times_df.dropna(subset = ["Birth Year"])
times_single_person_df.isna().sum()
# Out:
# Year                         0
# Honor                        0
# Name                         0
# Country                      0
# Birth Year                   0
# Death Year                  39
# Title                        2
# Category                     1
# Context                     17
# Unnamed: 9                  83
# Unnamed: 10                 92
# Age when recieving honor     0
# dtype: int64

# %%
times_single_person_df["Age when recieving honor"].mean()
# Out:
# 55.93617021276596

# %%
import matplotlib.pyplot as plt
times_fig, times_ax= plt.subplots()
times_single_person_df["Age when recieving honor"].plot(kind = "bar", ax = times_ax)
times_ax.axhline(times_single_person_df["Age when recieving honor"].mean(), color = "red")

# %% [markdown]
# ## Oldest Times nominee still allive today  (2022)

# %%
times_alive_df = times_single_person_df[times_single_person_df["Death Year"].isna()]
times_alive_df
# Out:
#      Year                Honor                                      Name  \
# 26   1952    Woman of the Year                              Elizabeth II
# 42   1968      Men of the Year      The Apollo 8 Astronauts (Jim Lovell)
# 43   1968      Men of the Year    The Apollo 8 Astronauts (Frank Borman)
# 44   1968      Men of the Year  The Apollo 8 Astronauts (William Anders)
# 53   1976      Man of the Year                              Jimmy Carter
# 58   1981      Man of the Year                               Lech Wałęsa
# 62   1984      Man of the Year                           Peter Ueberroth
# 65   1987      Man of the Year                         Mikhail Gorbachev
# 67   1989    Man of the Decade                         Mikhail Gorbachev
# 68   1990      Man of the Year                         George H. W. Bush
# 69   1991      Man of the Year                                Ted Turner
# 70   1992      Man of the Year                              Bill Clinton
# ...

# %%
times_alive_df[times_alive_df["Birth Year"] == times_alive_df["Birth Year"].min()]
# Out:
#     Year            Honor               Name        Country  Birth Year  \
# 53  1976  Man of the Year       Jimmy Carter  United States      1924.0
# 68  1990  Man of the Year  George H. W. Bush  United States      1924.0
#
#     Death Year                           Title  Category  \
# 53         NaN  President of the United States  Politics
# 68         NaN  President of the United States       War
#
#                   Context Unnamed: 9 Unnamed: 10  Age when recieving honor
# 53  Presidential Election        NaN         NaN                      52.0
# 68               Gulf War        NaN         NaN                      66.0
